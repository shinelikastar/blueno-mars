# %% [markdown]
# # Blueno Mars: Lyrics Generator using GPT-2
# Code adapted from `gpt-2-simple` tutorial by Max Woolf.
#
# **Getting started**:
#
#
# *   Go to Runtime -> Change runtime type and select GPU
# *   Run the cell below to verify that it's running with a GPU and import the libraries.

# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
# !nvidia-smi

import gpt_2_simple as gpt2
import tensorflow as tf
import os

from datetime import datetime
from google.colab import files
# Out:
# TensorFlow 1.x selected.
#   Building wheel for gpt-2-simple (setup.py) ... done
# Thu Dec 10 15:42:53 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   60C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# Download the model. We experimented with using the "small" 124M and "medium" 355M hyperparameter versions, and found the latter to give the best results. There are larger versions available, however, it's not possible to run them for free on the GPU provided by Google Colab.

# %%
gpt2.download_gpt2(model_name="355M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 272Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 123Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 481Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:05, 248Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 252Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 74.0Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 206Mit/s]

# %% [markdown]
# Load in corpus of 12,500 pop songs, scraped using the Genius API. The file is expected to be named `data.txt`.

# %%
gpt2.mount_gdrive()
big_corpus_file = "data.txt"
gpt2.copy_file_from_gdrive(big_corpus_file)
# Out:
# Mounted at /content/drive

# %% [markdown]
# When finetuning GPT-2, it has no sense of the beginning or end of a document within a larger text. We use `start_token` and `end_token` to indicate the beginning and end of a text.

# %%
start_token = "<|startoftext|>"
end_token = "<|endoftext|>"
line_break_token = "<|line_break|>"
verse_break_token = "<|verse_break|>"
unk_token = "<|UNK|>"

# %% [markdown]
# **Optional**: Parse into a smaller corpus of 3000 songs. This speeds up the training steps during fine-tuning. However, it's a tradeoff because the generated results are not as diverse in content and structure than fine-tuning on the larger corpus of 12,500 songs.

# %%
mini_corpus_file = "mini_corpus.txt"

with open(big_corpus_file, "r") as big_corpus, open(mini_corpus_file, "w") as mini_corpus:
  num_songs = 0

  for line in big_corpus.read().splitlines():
    if num_songs >= 3000:
      break

    if line == start_token:
      num_songs += 1
    else:
      mini_corpus.write(line + "\n")

mini_corpus.close()

# %% [markdown]
# Function to add in repeat tokens. We didn't do this originally in our preprocessing and had to write a script to add it in here. We found that the model learned to use "<|repeat|>" during fine-tuning, and the generated songs incorporate repetetive structure.

# %%
def add_repeat_tokens(input_file_name, repeat_file_name):
  with open(input_file_name, mode="r") as input_file, open(repeat_file_name, mode="w") as repeat_file:
    prev_line = ""

    for line in input_file.read().split("\n"):
      if line == prev_line:
        repeat_file.write("<|repeat|>\n")
      else:
        repeat_file.write(line + "\n")
        prev_line = line

# %% [markdown]
# If you want to use the smaller corpus of songs as the dataset to GPT-2, replace `big_corpus_file` with `mini_corpus_file` (loaded in above). The code snippet below adds in repeat tokens to the corpus of songs, and saves it to be passed as the dataset to `finetune`.

# %%
dataset = "with_repeat_data.txt"
add_repeat_tokens(big_corpus_file, dataset)

# %%
num_steps_per_epoch = 3000
num_epochs = 2
steps = num_steps_per_epoch * num_epochs

sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=dataset,
              model_name='355M',
              steps=steps,
              run_name='run1',
              print_every=10,
              sample_every=200,
              save_every=500,
              overwrite=True,
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint models/355M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/355M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:33<00:00, 33.76s/it]
# dataset has 9739866 tokens
# Training...
# Saving checkpoint/run1/model-0
# [10 | 23.89] loss=1.75 avg=1.75
# [20 | 39.00] loss=1.82 avg=1.78
# [30 | 54.29] loss=1.26 avg=1.61
# [40 | 69.90] loss=0.93 avg=1.43
# [50 | 85.81] loss=1.49 avg=1.45
# [60 | 101.93] loss=1.12 avg=1.39
# [70 | 118.45] loss=1.32 avg=1.38
# [80 | 135.42] loss=1.88 avg=1.44
# [90 | 152.65] loss=1.90 avg=1.50
# [100 | 169.42] loss=1.05 avg=1.45
# [110 | 186.07] loss=1.28 avg=1.43
# [120 | 202.81] loss=1.66 avg=1.45
# [130 | 219.82] loss=1.13 avg=1.43
# [140 | 236.85] loss=0.70 avg=1.37
# [150 | 253.69] loss=1.31 avg=1.37
# [160 | 270.55] loss=1.54 avg=1.38
# [170 | 287.60] loss=0.86 avg=1.35
# [190 | 321.67] loss=1.27 avg=1.32
# [200 | 338.55] loss=1.56 avg=1.33
# ======== SAMPLE 1 ========
# 'n'Nasty <|line_break|>
# but when it comes to sex n
# <|verse_break|>
# <|UNK|> <|line_break|>
# you <|UNK|> in my house <|line_break|>
# you <|UNK|> my house <|line_break|>
# you <|UNK|> <|UNK|> house <|line_break|>
# you <|UNK|> a house <|line_break|>
# you <|UNK|> inside a house door <|line_break|>
# <|UNK|> niggas house <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> got a <|UNK|> house <|line_break|>
# you <|line_break|>
# <|UNK|> in my house house <|line_break|>
# you <|line_break|>
# <|UNK|> in my house house <|line_break|>
# you <|line_break|>
# <|UNK|> <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> home <|line_break|>
# <|UNK|> <|line_break|>
# <|UNK|> <|UNK|> house <|UNK|> house <|line_break|>
# <|UNK|> <|line_break|>
# <|UNK|> <|line_break|>
# <|UNK|> man house <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> <|UNK|> <|UNK|> house <|line_break|>
# <|UNK|> in my house house <|line_break|>
# <|line_break|>
# you <|UNK|> <|line_break|>
# your <|UNK|> in my house <|line_break|>
#  you <|line_break|>
# <|UNK|> <|line_break|>
# <|UNK|> in my house <|line_break|>
# <|UNK|> house <|line_break|>
# <|line_break|>
# my house <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> <|UNK|> <|UNK|> <|line_break|>
# <|UNK|> <|UNK|> house <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> in my house <|line_break|>
# <|UNK|> <|UNK|> <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> in my house <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> <|UNK|> house <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> <|UNK|> <|line_break|>
# <|line_break|>
# <|UNK|> <|UNK|> <|UNK|> house <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> <|UNK|> <|UNK|> <|UNK|> <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> house <|line_break|>
# <|UNK|> <|UNK|> <|UNK|> <|line_break|>
# <|UNK|
#
# [210 | 380.40] loss=1.02 avg=1.31
# [220 | 397.44] loss=1.81 avg=1.34
# [230 | 414.44] loss=1.13 avg=1.33
# [240 | 431.50] loss=1.44 avg=1.33
# [250 | 448.65] loss=1.69 avg=1.35
# [260 | 465.79] loss=0.90 avg=1.33
# [270 | 482.96] loss=1.05 avg=1.32
# [280 | 500.05] loss=1.27 avg=1.32
# [290 | 517.14] loss=1.29 avg=1.31
# [300 | 534.27] loss=1.18 avg=1.31
# [310 | 551.35] loss=1.06 avg=1.30
# [320 | 568.45] loss=0.96 avg=1.29
# [330 | 585.49] loss=1.57 avg=1.30
# [340 | 602.59] loss=1.21 avg=1.30
# [350 | 619.68] loss=1.11 avg=1.29
# [360 | 636.77] loss=1.12 avg=1.28
# [370 | 653.82] loss=0.89 avg=1.27
# [380 | 670.84] loss=1.81 avg=1.29
# [390 | 687.93] loss=0.85 avg=1.27
# [400 | 704.96] loss=1.55 avg=1.28
# ======== SAMPLE 1 ========
# i' <|UNK|> <|line_break|>
# you'll know i'm a good girl i got something to say <|line_break|>
# that means i gotta tell you something to mean <|line_break|>
# baby the way you know it's me now <|line_break|>
# oh baby you know it's me now for me now
# <|endoftext|>
#
# <|startoftext|>
# i believe in you for me for me i want to keep you by my side <|line_break|>
# i wish you the best of everything you can be if you say the words that ya can
# <|verse_break|>
# i believe in you for me for me oh i want to keep you by my side
# <|verse_break|>
# oh i must have heard your cries <|line_break|>
# i believe in you for me for me oh i want to keep you by my side <|line_break|>
# i must have known something about you when you were alone with me but i don't know but it's not for sure
# <|verse_break|>
# i believe in you for me oh i want to keep you by my side oh i believe in you for me <|line_break|>
# oh i must have heard your cries oh i believe in you for me oh i want to keep you by my side oh i believe in you for me oh i believe in you for me oh i need to find a way to be with you
# <|verse_break|>
# oh i must have heard your cries oh i believe in you oh i want to keep you by my side oh i believe in you for me oh i for you oh i must have known something about you oh i must have known something about you oh i must have known something about you oh i had to know something about you oh my heart says oh
# <|verse_break|>
# what if we were to fall <|line_break|>
# baby and i'd be forever alone with you
# <|verse_break|>
# oh i must have heard your cries oh i must have known something about you oh i must have known something about you oh i must have knew something about you oh i must have known something about you oh i must have learned something about you oh i must have known something about you oh i must have known something about you oh i must have known something about you oh i must have known something about you oh i must have known something about you oh i must have known something about you oh i must have known something about you oh i must have known something about you oh i must have known something about you oh yea i have learned something about you oh all i have learned all about you oh all it's all it's all about oh all it's all about oh oh all it's all about oh all it's all about oh all it's all about oh all it's all about oh all it's all about oh all it's all about oh all it's all about oh all it's all about oh all it's all about oh all it's all about oh all it's all about oh oh all it's all about oh oh all it's all about oh oh
# <|verse_break|>
# oh i must have heard your cries oh i believe in you oh i must have knew something about you oh i must have known something about you oh i must have known something about you oh i must have known something about you oh i must have known something about you oh i must have known something about you oh i must know something about you oh i must have known something about you oh i must know something about you oh i must know something about you oh i must know something about you oh i must know something about you oh i must know something about you oh i must know something about you oh i must know something about you oh
# <|verse_break|>
# oh i must have heard your cries oh i must have known something about you oh i must have known something about you oh i must know something about you oh i must know something about you oh i must know something about you oh i must know something about you oh i must know something about you oh i must know something about you oh oh i must know something about you oh oh i must know something about you oh oh oh oh oh oh i must know something about you oh oh oh oh oh oh
# <|verse_break|>
# oh i must have heard your cries oh i must have known something about you oh i must know something about you oh i must know something about you oh i must know something about you oh i must know something about you oh i must know something about you oh
# <|verse_break|>
# oh i must have heard your cries oh i must have known something about you oh i must know something about you oh i must know something about you oh i must know
#
# [410 | 744.09] loss=1.14 avg=1.28
# [420 | 761.08] loss=1.12 avg=1.27
# [430 | 778.26] loss=1.13 avg=1.27
# [440 | 795.38] loss=0.86 avg=1.26
# [450 | 812.51] loss=1.41 avg=1.26
# [460 | 829.57] loss=1.63 avg=1.27
# [470 | 846.64] loss=1.52 avg=1.28
# [480 | 863.75] loss=1.43 avg=1.28
# [490 | 880.84] loss=1.37 avg=1.29
# [500 | 897.90] loss=1.53 avg=1.29
# Saving checkpoint/run1/model-500
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# [510 | 921.63] loss=1.68 avg=1.30
# [520 | 939.34] loss=2.02 avg=1.32
# [530 | 956.47] loss=1.42 avg=1.32
# [540 | 973.33] loss=1.20 avg=1.32
# [550 | 990.22] loss=0.90 avg=1.31
# [560 | 1007.58] loss=0.78 avg=1.30
# [570 | 1024.83] loss=1.54 avg=1.30
# [580 | 1041.86] loss=1.20 avg=1.30
# [590 | 1058.88] loss=1.33 avg=1.30
# [600 | 1075.94] loss=1.97 avg=1.31
# ======== SAMPLE 1 ========
# _break|>
# i can get you up off your pants <|line_break|>
# you're the only one that matters i'm ready
# <|verse_break|>
# i'm not looking for a friend i'm looking for a lover <|line_break|>
# i may not have the right <|UNK|> that you <|UNK|> <|line_break|>
# but i promise tonight tonight you will be the <|UNK|> that I'm <|UNK|>
# <|endoftext|>
#
# <|startoftext|>
# <|UNK|> <|UNK|> from your <|UNK|> <|line_break|>
# <|UNK|> as <|UNK|> <|UNK|> <|line_break|>
# now you're a hmm ah ah uhh you're ah ah ah ah ah ah
# <|verse_break|>
# i've heard your <|UNK|> you know my <|UNK|> um ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah > ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah
# <|verse_break|>
# i need you <|UNK|> <|UNK|> the <|UNK|> <|line_break|>
# you got your <|UNK|> uh <|line_break|>
# your <|UNK|> ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah <|UNK|> ah ah ah ah ah ah ah
# <|verse_break|>
# i'm not looking for a friend i'm looking for a lover <|line_break|>
# i may not have the right <|UNK|> that you <|UNK|> <|line_break|>
# but i promise tonight tonight you will be the <|UNK|> that i'm <|UNK|>
# <|verse_break|>
# i've heard your <|UNK|> you know my <|UNK|> um ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah
# <|endoftext|>
#
# <|startoftext|>
# hah <|UNK|> <|UNK|> <|UNK|> <|UNK|> <|line_break|>
# i don't ever need <|UNK|> more than you <|UNK|> <|UNK|> <|line_break|>
# i think you're the only one i need <|line_break|>
# i got a little love in my heart <|line_break|>
# i got a <|UNK|> in my mouth just to hold the <|UNK|> <|line_break|>
# i'm not the type that wanna be rude to a friend <|line_break|>
# but i know you're my friend and i love you <|line_break|>
# and i've had a love on the internet <|line_break|>
# you think that i have a <|UNK|> but i just wanna share the love with you
# <|verse_break|>
# uh uhh uh ah ah ah ah ah ah
# <|verse_break|>
# i'm a <|UNK|> <|UNK|> with a <|UNK|> <|line_break|>
# it's time to take my <|UNK|> out the hood <|line_break|>
# <|UNK|> with a <|UNK|> ah ah ah ah <|line_break|>
# i know you're my friend and i love you <|UNK|> ah ah ah ah ah ah ah ah ah ah
# <|verse_break|>
# i'm a <|UNK|> wokah i guess i'm <|UNK|> with a <|UNK|> ah <|line_break|>
# i think he's <|UNK|> for the day and i need you more than you <|line_break|>
# i need you more than i want to be <|line_break|>
# it's
#
# [610 | 1115.24] loss=1.80 avg=1.33
# [620 | 1132.22] loss=1.19 avg=1.32
# [630 | 1149.35] loss=0.78 avg=1.31
# [640 | 1166.54] loss=1.00 avg=1.30
# [650 | 1183.69] loss=1.24 avg=1.30
# [660 | 1200.70] loss=1.47 avg=1.31
# [670 | 1217.75] loss=1.89 avg=1.32
# [680 | 1234.78] loss=1.45 avg=1.32
# [690 | 1251.84] loss=1.08 avg=1.32
# [700 | 1268.89] loss=1.81 avg=1.33
# [710 | 1285.94] loss=1.41 avg=1.33
# [720 | 1302.99] loss=1.33 avg=1.33
# [730 | 1320.00] loss=0.97 avg=1.32
# [740 | 1337.08] loss=1.33 avg=1.32
# [750 | 1354.13] loss=1.43 avg=1.32
# [760 | 1371.21] loss=2.16 avg=1.34
# [770 | 1388.33] loss=1.02 avg=1.33
# [780 | 1405.37] loss=1.40 avg=1.33
# [790 | 1422.47] loss=1.26 avg=1.33
# [800 | 1439.54] loss=1.59 avg=1.34
# ======== SAMPLE 1 ========
# i is right here <|line_break|>
# there is nobody like her when i call her <|UNK|> <|line_break|>
# <|repeat|>
# when i am with her she is in heaven with me <|line_break|>
# that is enough to know if she is with you or not
# <|endoftext|>
#
# <|startoftext|>
# she says she <|UNK|> with a man she's got a car <|line_break|>
# we got a car she got a <|UNK|> <|UNK|> <|line_break|>
# yeah we got a car and we'm doing <|UNK|> <|line_break|>
# in this song
# <|endoftext|>
#
# <|startoftext|>
# let's hear it
# <|verse_break|>
# i don't want a new car <|line_break|>
# let's do one for new
# <|verse_break|>
# oh baby oh baby oh baby <|line_break|>
# oh hello honey <|line_break|>
# oh hello honey
# <|verse_break|>
# hey hey j's on my way <|line_break|>
# <|repeat|>
# hey hey j's on my way <|line_break|>
# hey hey j's on my way <|line_break|>
# <|repeat|>
# hey hey j's on my way <|line_break|>
# hey hey j's on my way
# <|verse_break|>
# let's do one for new
# <|verse_break|>
# hey hey j's on my way <|line_break|>
# <|repeat|>
# hey hey j's on my way
# <|verse_break|>
# hey hey j's on my way <|line_break|>
# hey hey j's on my way <|line_break|>
# hey hey j's on my way
# <|endoftext|>
#
# <|startoftext|>
# you're the only thing <|line_break|>
# that i can touch <|UNK|> <|line_break|>
# you're the only thing <|line_break|>
# that i can feel <|line_break|>
# you're the only thing <|line_break|>
# that i can touch <|line_break|>
# you're the only thing <|line_break|>
# you're the only thing you're my love you'll know just who i am <|line_break|>
# you're <|UNK|> <|line_break|>
# you might break the magic barrier <|line_break|>
# you might break the magic barrier
# <|verse_break|>
# i'll be <|UNK|> with you <|line_break|>
# i'll be <|UNK|> with you <|line_break|>
# i'll be taking you away <|line_break|>
# i'll be laying me low be <|UNK|> with you <|line_break|>
# <|repeat|>
# be <|UNK|> with you
# <|verse_break|>
# hey hey j's on my way <|line_break|>
# <|repeat|>
# hey hey j's on my way <|line_break|>
# hey hey j's on my way
# <|verse_break|>
# yeah i'll be <|UNK|> with you yeah <|line_break|>
# <|repeat|>
# the way that i love you
# <|verse_break|>
# hey hey j's on my way <|line_break|>
# hey hey j's on my way <|line_break|>
# hey hey j's on my way
# <|verse_break|>
# i'll be <|UNK|> with you i'll be <|UNK|> with you i'll be <|line_break|>
# <|repeat|>
# i won't know if i wanna go 'fore i can just stay by a little more <|line_break|>
# <|repeat|>
# i know this isn't <|UNK|> yet <|line_break|>
# i'll be <|UNK|> with you <|line_break|>
# i won't know when or where or to who but i'll <|line_break|>
# stay in a little bit more <|line_break|>
# wait the love isn't <|UNK|> yet <|line_
#
# [810 | 1478.88] loss=1.08 avg=1.33
# [820 | 1495.85] loss=1.41 avg=1.33
# [830 | 1512.99] loss=1.05 avg=1.33
# [840 | 1530.22] loss=1.57 avg=1.33
# [850 | 1547.37] loss=1.89 avg=1.34
# [860 | 1564.38] loss=0.99 avg=1.34
# [870 | 1581.38] loss=1.02 avg=1.33
# [880 | 1598.41] loss=1.62 avg=1.34
# [890 | 1615.46] loss=1.15 avg=1.33
# [900 | 1632.52] loss=1.12 avg=1.33
# [910 | 1649.58] loss=1.17 avg=1.33
# [920 | 1666.66] loss=1.13 avg=1.32
# [930 | 1683.72] loss=1.13 avg=1.32
# [940 | 1700.83] loss=1.05 avg=1.32
# [950 | 1717.92] loss=1.85 avg=1.32
# [960 | 1734.99] loss=0.82 avg=1.32
# [970 | 1752.08] loss=0.81 avg=1.31
# [980 | 1769.13] loss=1.23 avg=1.31
# [990 | 1786.22] loss=1.60 avg=1.31
# [1000 | 1803.27] loss=1.12 avg=1.31
# Saving checkpoint/run1/model-1000
# ======== SAMPLE 1 ========
# |>
# i'm a <|UNK|> up <|line_break|>
# i'm <|UNK|> up <|line_break|>
# i'm a <|UNK|> up <|line_break|>
# i'm a <|UNK|> up up up up <|line_break|>
# i'm a <|UNK|> up
# <|endoftext|>
#
# <|startoftext|>
# <|UNK|> <|UNK|>
# <|verse_break|>
# we don't even know <|line_break|>
# if i'm living or dead <|line_break|>
# we don't even know <|line_break|>
# if i look around at my teammates <|line_break|>
# we don't even know <|line_break|>
# if i look at them <|line_break|>
# we don't even know where to look <|line_break|>
# we don't even know what to do <|line_break|>
# we're just living on a <|UNK|> <|line_break|>
# <|UNK|> is a phrase usually used to describe someone you've been told has <|UNK|> themselves <|line_break|>
# <|UNK|> <|UNK|> is an <|UNK|> and used to define any <|UNK|> that they've <|UNK|> themselves <|line_break|>
# all we know is that i'm on the team we can identify you <|line_break|>
# but right now we can't tell who is me <|line_break|>
# because right now we can't tell where <|line_break|>
# to look <|line_break|>
# we don't even know where to look right now
# <|verse_break|>
# we don't even know oh <|line_break|>
# if i'm living or dead <|line_break|>
# we don't even know oh <|line_break|>
# if i look around at my teammates <|line_break|>
# we don't even know i'm on the team <|line_break|>
# we don't even know <|line_break|>
# if i look around at my teammates <|line_break|>
# we don't even know where to look <|line_break|>
# we don't even know what to do <|line_break|>
# we're just living on a <|UNK|> <|line_break|>
# <|UNK|> is a phrase usually used to describe someone you've been told has <|UNK|> themselves <|line_break|>
# <|UNK|> <|UNK|> is an <|UNK|> and used to describe any <|UNK|> or <|UNK|> that they've had or <|UNK|> themselves <|line_break|>
# all we know is that i'm on the team we can identify you <|line_break|>
# but right now we can't tell who is me <|line_break|>
# because right now we can't tell where <|line_break|>
# to look <|line_break|>
# we don't even know where to look right now
# <|verse_break|>
# we don't even know oh <|line_break|>
# if i'm living or dead <|line_break|>
# we don't even know oh <|line_break|>
# if i look around at my teammates <|line_break|>
# we don't even know i'm on the team <|line_break|>
# we don't even know <|line_break|>
# if i look around at my teammates <|line_break|>
# we don't even know where to look <|line_break|>
# we don't even know what to do <|line_break|>
# we're just living on a <|UNK|> <|line_break|>
# <|UNK|> is a phrase usually used to describe anyone you've been left behind <|line_break|>
# right now we've got a <|UNK|> for <|UNK|> our hearts <|line_break|>
# they'll be <|UNK|> a different name a while later <|line_break|>
# but right now we don't really have a reason to keep a <|UNK|> <|line_break|>
# yeah right now <
#
# [1010 | 1849.80] loss=1.00 avg=1.30
# [1020 | 1866.77] loss=0.84 avg=1.30
# [1030 | 1883.65] loss=0.97 avg=1.29
# [1040 | 1900.68] loss=1.14 avg=1.29
# [1050 | 1917.92] loss=1.21 avg=1.29
# [1060 | 1935.02] loss=1.10 avg=1.29
# [1070 | 1952.06] loss=1.39 avg=1.29
# [1080 | 1969.05] loss=1.12 avg=1.28
# [1090 | 1986.11] loss=1.66 avg=1.29
# [1100 | 2003.21] loss=0.94 avg=1.28
# [1110 | 2020.32] loss=1.37 avg=1.29
# [1120 | 2037.51] loss=0.80 avg=1.28
# [1130 | 2054.62] loss=1.20 avg=1.28
# [1140 | 2071.75] loss=1.24 avg=1.28
# [1150 | 2088.91] loss=1.46 avg=1.28
# [1160 | 2106.06] loss=1.03 avg=1.28
# [1170 | 2123.17] loss=1.38 avg=1.28
# [1180 | 2140.27] loss=1.09 avg=1.27
# [1190 | 2157.41] loss=1.16 avg=1.27
# [1200 | 2174.51] loss=0.75 avg=1.27
# ======== SAMPLE 1 ========
# break|>
# i just don't like it when i'm feeling scared
# <|verse_break|>
# 'cause i'm not afraid it's what's real for me
# <|verse_break|>
# i've got a good thing goin' on <|line_break|>
# i'm not afraid it's what's real for me <|line_break|>
# i'm not afraid it's what's real for me
# <|verse_break|>
# no i don't want it to end so soon <|line_break|>
# that i'm not alone
# <|verse_break|>
# 'cause i don't want it to end so soon <|line_break|>
# i don't want it just because i got it <|line_break|>
# oh yeah i just don't like it when i'm feeling scared
# <|verse_break|>
# 'cause i'm not afraid it's what's real for me
# <|verse_break|>
# i've got a good thing goin' on
# <|verse_break|>
# i'm not afraid it's what's real for me <|line_break|>
# i'm not afraid it's what's real for me
# <|verse_break|>
# i'm not afraid it's what's real for me
# <|verse_break|>
# 'cause i don't get it why i don't get it <|line_break|>
# i'm a man i'm a man i don't get it <|line_break|>
# oh so you don't get it get the idea <|line_break|>
# and i don't get it i get it <|line_break|>
# i don't get it get it
# <|verse_break|>
# 'cause i don't get it why i don't get it
# <|verse_break|>
# in case you didn't get it <|line_break|>
# in case you didn't get it <|line_break|>
# in case you didn't get it
# <|verse_break|>
# <|UNK|> uh uh we ain't getting off the ground <|line_break|>
# i'm a man i'm a man i'm a man i'm a man
# <|verse_break|>
# 'cause i don't get it why i don't get it <|line_break|>
# i'm a man i'm a man i'm a man i'm a man
# <|verse_break|>
# we are a man we are a man
# <|verse_break|>
# and i'ma be a man i'm on the road to success <|line_break|>
# i'm a man i'm a man i'm a man i'm a man i'm a man i'm a man with a man i'm a man with a man
# <|verse_break|>
# 'cause i don't get it why i don't get it <|line_break|>
# i'm a man i'm a man i'm a man i'm a man i'm a man i'm a man i'm a man i'm a man with a man i'm a man with a man i'm a man with a man i'm a man with a man i'm a man with a man i'm a man with a man i'm a man with a man i'm a man with a man ooh <|line_break|>
# 'cause i don't get it why i don't get it <|line_break|>
# so if you wanna say it to the world
# <|verse_break|>
# i'm not afraid it's what's real for me <|line_break|>
# i'm not afraid it's what's real for me
# <|verse_break|>
# 'cause i don't get it why i don't get it
# <|verse_break|>
# and if you wanna hit it with a <|UNK|> like <|line_break|>
# and if you wanna say it to the world
# <|verse_break|>
# i'm a man i'm a man i'm a man i'm a man i'm a man i'm a man
# <|endoftext|>
#
# <|startoftext|>
# i don't know what you think she's talking about <|line_break|>
# we don't even know if <|line_break|>
# i got me some <|UNK|> <|line_break|>
# you were going to come clean now you've found a problem
# <|verse_break|>
# it's so hard that i can't even begin to tell what you do <|line_break|>
#
#
# [1210 | 2213.80] loss=1.26 avg=1.27
# [1220 | 2230.80] loss=1.40 avg=1.27
# [1230 | 2248.00] loss=1.20 avg=1.27
# [1240 | 2265.11] loss=0.98 avg=1.26
# [1250 | 2282.13] loss=1.14 avg=1.26
# [1260 | 2299.14] loss=0.74 avg=1.25
# [1270 | 2316.23] loss=1.33 avg=1.25
# [1280 | 2333.39] loss=0.78 avg=1.25
# [1290 | 2350.59] loss=0.80 avg=1.24
# [1300 | 2367.69] loss=1.25 avg=1.24
# [1310 | 2384.72] loss=0.98 avg=1.24
# [1320 | 2401.75] loss=1.22 avg=1.24
# [1330 | 2418.78] loss=1.86 avg=1.25
# [1340 | 2435.79] loss=1.69 avg=1.25
# [1350 | 2452.77] loss=1.09 avg=1.25
# [1360 | 2469.82] loss=0.73 avg=1.24
# [1370 | 2486.98] loss=1.20 avg=1.24
# [1380 | 2504.14] loss=1.94 avg=1.25
# [1390 | 2521.23] loss=1.44 avg=1.25
# [1400 | 2538.24] loss=1.25 avg=1.25
# ======== SAMPLE 1 ========
#  up
# <|verse_break|>
# when she says a <|UNK|> <|line_break|>
# she says a <|UNK|> <|line_break|>
# where would i go if i told ya baby i've heard it all but not this one <|line_break|>
# all over <|UNK|> so where have i been
# <|verse_break|>
# i don't think of it like
# <|verse_break|>
# oh all over that's what you call it <|line_break|>
# all over that's what you call it and i thought you would know but not this one
# <|verse_break|>
# you don't really understand it but i hear it like
# <|verse_break|>
# yeah you don't really comprehend it but i hear it
# <|verse_break|>
# i don't really understand it but i hear it baby <|line_break|>
# all over that's what you call it all over that's what you do <|line_break|>
# you don't really understand it but i hear it like i'm saying <|line_break|>
# you don't really comprehend it but i hear it
# <|verse_break|>
# but baby it's a trap now <|line_break|>
# you don't really understand it but i hear it like all over that's what you say
# <|verse_break|>
# i don't really understand it but i hear it like that <|line_break|>
# <|repeat|>
# <|repeat|>
# it's a trap baby <|line_break|>
# oh i hear it now <|line_break|>
# it's a trap <|line_break|>
# it's a trap
# <|verse_break|>
# where have i been <|line_break|>
# it's a trap baby
# <|verse_break|>
# i don't really understand it but i hear it like
# <|verse_break|>
# i don't really understand it but i hear it <|line_break|>
# i don't really understand it but i hear it now
# <|verse_break|>
# it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap <|line_break|>
# its a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap baby it's a trap
# <|endoftext|>
#
# <|startoftext|>
# <|UNK|> with your <|UNK|> <|line_break|>
# <|repeat|>
# <|UNK|> with your <|UNK|> <|line_break|>
# <|repeat|>
# you with your <|UNK|> <|line_break|>
# <|repeat|>
# <|repeat|>
# you with your <|UNK|>
# <|verse_break|>
# let yourself be <|line_break|>
# let yourself go <|line_break|>
# don't fall in love <|line_break|>
# you want it all now <|line_break|>
# let yourself be <|line_break|>
# let yourself go <|line_break|>
# <|repeat|>
# <|repeat|>
# <|repeat|>
# <|repeat|>
# <|repeat|>
# <|repeat|>
# you with your <|UNK|> now <|line_break|>
# let yourself be <|line_break|>
# let yourself go
# <|verse_break|>
# and you won't need my ring <|line_break|>
# you'll only <|UNK|> my <|UNK|> <|line_break|>
# the place was <|UNK|>
# <|verse_break|>
# i heard a voice <|line_break|>
# i thought you must have known <|line_break|>
# he would come and save you
# <|verse_break|>
# oh what you want is that heart <|line_break|>
# you want it
#
# [1410 | 2577.86] loss=1.27 avg=1.25
# [1420 | 2594.87] loss=1.48 avg=1.26
# [1430 | 2611.81] loss=0.67 avg=1.25
# [1440 | 2628.80] loss=1.86 avg=1.26
# [1450 | 2645.97] loss=1.51 avg=1.26
# [1460 | 2663.06] loss=1.63 avg=1.27
# [1470 | 2680.09] loss=1.38 avg=1.27
# [1480 | 2697.06] loss=0.90 avg=1.26
# [1490 | 2714.11] loss=1.12 avg=1.26
# [1500 | 2731.32] loss=1.18 avg=1.26
# Saving checkpoint/run1/model-1500
# [1510 | 2754.95] loss=0.86 avg=1.25
# [1520 | 2772.46] loss=1.32 avg=1.26
# [1530 | 2789.63] loss=1.40 avg=1.26
# [1540 | 2806.65] loss=0.78 avg=1.25
# [1550 | 2823.70] loss=1.24 avg=1.25
# [1560 | 2840.75] loss=1.42 avg=1.25
# [1570 | 2857.81] loss=0.93 avg=1.25
# [1580 | 2874.85] loss=1.32 avg=1.25
# [1590 | 2891.99] loss=1.18 avg=1.25
# [1600 | 2909.11] loss=1.57 avg=1.25
# ======== SAMPLE 1 ========
# Kofu <|line_break|>
# to the sea <|line_break|>
# doom to a <|UNK|> with good heart <|line_break|>
# the <|UNK|> <|UNK|> the game and it <|line_break|>
# i've got this bad heart and it's a love in it <|line_break|>
# and oh i'm so bad if you think i'm a bad guy <|line_break|>
# and if you were an angel angel would you come around me <|line_break|>
# if i was a woman i'd probably just say bye
# <|verse_break|>
# my heart is a woman's heart <|line_break|>
# and i'm always gonna fight just like a man <|line_break|>
# and if you tried to stop me you'd probably win <|line_break|>
# so i'm just saying i gotta hold out a little more time <|line_break|>
# to get past this <|line_break|>
# like the <|UNK|> of <|UNK|> <|line_break|>
# to the sea <|line_break|>
# doom to a <|UNK|> with good heart <|line_break|>
# the <|UNK|> <|UNK|> on it the heart is a woman's heart <|line_break|>
# and i'm always gonna fight just like a man <|line_break|>
# and if you tried to stop me you'd probably win <|line_break|>
# so i'm just saying i gotta hold out a little more time <|line_break|>
# to get past this <|line_break|>
# like the <|UNK|> of <|UNK|> <|line_break|>
# to the sea <|line_break|>
# doom to a <|UNK|> with good heart <|line_break|>
# the <|UNK|> on it the heart is a woman's heart <|line_break|>
# and i'm always gonna fight just like a man <|line_break|>
# and if you tried to stop me you'd probably win <|line_break|>
# so i'm just saying i gotta hold out a little more time <|line_break|>
# to get past this or the like the <|line_break|>
# doom to a woman with good heart <|line_break|>
# the heart is a woman's heart <|line_break|>
# and i'm always gonna fight just like a man <|line_break|>
# and if you tried to stop me you'd probably win <|line_break|>
# so i'm just like ahh ah ohh you like a man <|line_break|>
# so let me know that i'm not alone let me see her oh yeah <|line_break|>
# 'cause i'm a <|UNK|> and she doesn't have a heart of gold like a <|UNK|>
# <|verse_break|>
# i'm gonna hold on <|line_break|>
# i'm gonna stay on <|line_break|>
# i'm gonna hold on <|line_break|>
# i'm gonna stay on hold on hold on hold off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off off offoff offoff offoff offoffoff <|line_break|>
# i'm gonna hold on hold on holdon holdon holdon holdon holdon holdon holdon holdon holdon holdon holdon holdon holdon holdon holdon holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton holdton have a lot in you but no one else can hear <|line_break|>
# hold on holdon holdon holdon holdon holdon holdon holdon holdon holdon holdon <|line_break|>
# hold on holdon holdon holdon holdon holdon holdon holdingon holdon holdon holdon holdon holdon holdon holdon holdon holdon holdon holdon holdon holdon holdon holdon holdon holdon <|line_break|>
#
# [1610 | 2948.09] loss=1.27 avg=1.25
# [1620 | 2965.05] loss=1.09 avg=1.25
# [1630 | 2982.18] loss=1.44 avg=1.25
# [1640 | 2999.28] loss=0.95 avg=1.25
# [1650 | 3016.39] loss=1.18 avg=1.25
# [1660 | 3033.42] loss=1.12 avg=1.25
# [1670 | 3050.46] loss=0.62 avg=1.24
# [1680 | 3067.58] loss=1.03 avg=1.24
# [1690 | 3084.67] loss=1.69 avg=1.24
# [1700 | 3101.76] loss=0.95 avg=1.24
# [1710 | 3118.77] loss=1.39 avg=1.24
# [1720 | 3135.82] loss=1.36 avg=1.24
# [1730 | 3152.93] loss=1.29 avg=1.24
# [1740 | 3170.03] loss=1.55 avg=1.25
# [1750 | 3187.12] loss=1.17 avg=1.25
# [1760 | 3204.15] loss=1.06 avg=1.24
# [1770 | 3221.23] loss=1.49 avg=1.25
# [1780 | 3238.31] loss=0.94 avg=1.24
# [1790 | 3255.44] loss=0.69 avg=1.24
# [1800 | 3272.60] loss=2.01 avg=1.25
# ======== SAMPLE 1 ========
# > <|line_break|>
# i know all these girls would love to come and spend an evening with you but we ain't having no party
# <|verse_break|>
# we ain't got a thing <|line_break|>
# but the stars are blinding <|line_break|>
# we're blinded by the <|UNK|>
# <|endoftext|>
#
# <|startoftext|>
# don't ask me for anything <|line_break|>
# don't ask me for nothing <|line_break|>
# <|UNK|> <|UNK|> it don't matter <|line_break|>
# it just a moment <|line_break|>
# but you'll regret it <|line_break|>
# what did you do to me
# <|verse_break|>
# but i'm not afraid <|line_break|>
# you're only making me doubt <|line_break|>
# whoa you're always there <|line_break|>
# and you're not happy when i'm with you <|line_break|>
# and we don't have no time for you <|line_break|>
# don't ever call me <|line_break|>
# i'll be around <|line_break|>
# for a long time <|line_break|>
# i've given my <|UNK|> <|line_break|>
# so if you want to move along with me <|line_break|>
# and if you want to keep your shit <|line_break|>
# if you don't want to see the <|UNK|> <|line_break|>
# i'll be around <|line_break|>
# for a while
# <|verse_break|>
# and if i'm not around <|line_break|>
# if you're with someone else <|line_break|>
# and i've been away from you <|line_break|>
# and i can't hear what you're saying <|line_break|>
# if i'm not around <|line_break|>
# because you're not doing well <|line_break|>
# i don't want i wish <|line_break|>
# all i need is you to know the damage <|line_break|>
# what's been done to me
# <|verse_break|>
# but this shit might have been worse anyway <|line_break|>
# oh i'm not scared <|line_break|>
# you're just a woman <|line_break|>
# that's all
# <|endoftext|>
#
# <|startoftext|>
# can't forget about the <|UNK|> <|line_break|>
# can't forget about the <|UNK|> <|line_break|>
# you gotta have a man <|line_break|>
# tell me if that don't change <|line_break|>
# but i ain't never been there <|line_break|>
# when you're gone you're gone <|line_break|>
# i just went ahead and did it <|line_break|>
# if you don't keep talking shit <|line_break|>
# i'll have to tell you
# <|verse_break|>
# you can't come back again
# <|verse_break|>
# i think you came for me <|line_break|>
# and i think it was just <|line_break|>
# a show of hands you don't even care <|line_break|>
# all the girls that were friends you've never spoken to <|line_break|>
# i'll never let you around me
# <|verse_break|>
# you came to make me <|line_break|>
# you came to be my man <|line_break|>
# but the only thing that came between us
# <|verse_break|>
# can't forget about the <|UNK|> <|line_break|>
# can't forget about the <|UNK|> <|line_break|>
# you gotta have a man <|line_break|>
# tell me if that don't change <|line_break|>
# but i ain't never been there for you <|line_break|>
# i gotta tell you
# <|verse_break|>
# that's what you need <|line_break|>
# <|UNK|> like you gotta <|UNK|> <|line_break|>
# to get me <|line_break|>
# i'm gone out the door <
#
# [1810 | 3312.53] loss=1.22 avg=1.25
# [1820 | 3329.49] loss=1.05 avg=1.24
# [1830 | 3346.56] loss=1.85 avg=1.25
# [1840 | 3363.72] loss=0.74 avg=1.24
# [1850 | 3380.86] loss=1.39 avg=1.25
# [1860 | 3397.97] loss=1.38 avg=1.25
# [1870 | 3415.00] loss=1.16 avg=1.25
# [1880 | 3432.03] loss=1.26 avg=1.25
# [1890 | 3449.05] loss=1.03 avg=1.24
# [1900 | 3466.08] loss=1.12 avg=1.24
# [1910 | 3483.11] loss=1.30 avg=1.24
# [1920 | 3500.15] loss=0.88 avg=1.24
# [1930 | 3517.20] loss=1.13 avg=1.24
# [1940 | 3534.25] loss=1.45 avg=1.24
# [1950 | 3551.28] loss=0.63 avg=1.23
# [1960 | 3568.35] loss=1.61 avg=1.24
# [1970 | 3585.39] loss=0.75 avg=1.23
# [1980 | 3602.46] loss=0.94 avg=1.23
# [1990 | 3619.54] loss=1.04 avg=1.23
# [2000 | 3636.62] loss=1.44 avg=1.23
# Saving checkpoint/run1/model-2000
# ======== SAMPLE 1 ========
#  make me believe in you no more <|line_break|>
# and all these dreams and visions of the way you used to love me <|line_break|>
# my only doubt is i'm just your enemy now i'm so glad <|line_break|>
# here it comes it comes
# <|endoftext|>
#
# <|startoftext|>
# we are <|line_break|>
# we are <|UNK|> <|line_break|>
# we are <|UNK|> <|UNK|> <|line_break|>
# we are dancing <|line_break|>
# we are singing hey you're <|UNK|> hey it's <|line_break|>
# our time <|line_break|>
# <|UNK|>
# <|verse_break|>
# i don't think it was easy <|line_break|>
# but i guess that's what you wanted <|line_break|>
# we were in the <|UNK|> that you'd <|UNK|> <|line_break|>
# there wasn't much that could be done <|line_break|>
# wasn't nobody on you <|line_break|>
# in the end was all you had baby it was you <|line_break|>
# it was easy <|line_break|>
# it never was easy <|line_break|>
# all you had was me babe <|line_break|>
# and our world is falling apart <|line_break|>
# you're still there <|line_break|>
# you still can get up <|line_break|>
# and leave before you say goodbye <|line_break|>
# it was easy you say goodbye <|line_break|>
# easy it was easy <|line_break|>
# it was easy it was easy easy easy easy easy easy easy easy <|line_break|>
# it was easy easy easy easy easy easy easy easy easy easy easy easy easy easy easy easy easy easy soft easy easy yeah easy easy easy easy easy easy easy ease soft easy easy <|line_break|>
# easy easy easy easy easy easy easy easy easy easy easy easy easy easy easy easy easy easy easy
# <|endoftext|>
#
# <|startoftext|>
# oh <|UNK|> <|line_break|>
# ooh <|UNK|> <|UNK|> <|line_break|>
# oh yeah yeah yeah <|line_break|>
# ooh <|line_break|>
# ooh <|line_break|>
# ooh yeah yeah yeah oh yeah <|line_break|>
# ooh
# <|verse_break|>
# <|UNK|> uh-huh i love it when you call me sweet <|line_break|>
# ooh i love it when you call me sweet <|line_break|>
# ooh i love it when i call the number <|line_break|>
# ooh i love it when you say <|line_break|>
# ooh yeah yeah <|line_break|>
# ooh yeah yeah yeah oh
# <|verse_break|>
# ooh oh oh yeah <|line_break|>
# i don't think we ever got into mischief <|line_break|>
# yeah i know i love it when you call me sweet <|line_break|>
# ooh i love it when you call me sweet yeah i love it when i call the number <|line_break|>
# ooh yeah yeah yeah oh yeah <|line_break|>
# ooh
# <|verse_break|>
# ooh yeah yeah <|line_break|>
# ooh yeah yeah ooh <|line_break|>
# oh yeah yeah yeah oh yeah yeah <|line_break|>
# ooh yeah yeah yeah oh yeah yeah
# <|verse_break|>
# ooh yeah yeah yeah yeah let me <|line_break|>
# ooh <|line_break|>
# ooh yeah yeah yeah let me <|line_break|>
# ooh yeah yeah yeah let me
# <|verse_break|>
# hey <|line_break|>
# it's nice to have friends <|line_break|>
# so i thought it was time to get over <|line_break|>
# 'cause i'm coming home <|line_break|>
# so i figured i better just hit the rush yeah
# <|verse_break|>
# oh yeah <|line_break|>
# ooh yeah yeah <|line_break|>
#
# [2010 | 3683.34] loss=1.31 avg=1.23
# [2020 | 3700.35] loss=1.82 avg=1.24
# [2030 | 3717.28] loss=1.11 avg=1.23
# [2040 | 3734.35] loss=1.02 avg=1.23
# [2050 | 3751.52] loss=1.04 avg=1.23
# [2060 | 3768.65] loss=1.03 avg=1.23
# [2070 | 3785.68] loss=1.76 avg=1.23
# [2080 | 3802.70] loss=1.46 avg=1.24
# [2090 | 3819.75] loss=1.41 avg=1.24
# [2100 | 3836.86] loss=1.08 avg=1.24
# [2110 | 3854.10] loss=1.06 avg=1.23
# [2120 | 3871.26] loss=0.71 avg=1.23
# [2130 | 3888.34] loss=0.99 avg=1.23
# [2140 | 3905.40] loss=1.68 avg=1.23
# [2150 | 3922.44] loss=1.19 avg=1.23
# [2160 | 3939.48] loss=0.90 avg=1.23
# [2170 | 3956.52] loss=1.18 avg=1.23
# [2180 | 3973.57] loss=1.06 avg=1.22
# [2190 | 3990.58] loss=1.13 avg=1.22
# [2200 | 4007.71] loss=1.60 avg=1.23
# ======== SAMPLE 1 ========
# >
# so now the <|UNK|> can't see me anymore <|line_break|>
# i'm alone <|UNK|> <|line_break|>
# we can't see the past <|line_break|>
# as i'm waiting to go <|endoftext|>
#
# <|startoftext|>
# <|UNK|> <|line_break|>
# oh i'm a mess <|line_break|>
# oh i'm so sorry
# <|verse_break|>
# <|UNK|> <|line_break|>
# oh i'm a mess oh <|line_break|>
# <|UNK|> yeah <|line_break|>
# oh i'm so sorry
# <|verse_break|>
# oh i'm so sorry
# <|verse_break|>
# oh so sorry oh
# <|endoftext|>
#
# <|startoftext|>
# there's nothing in this life <|line_break|>
# just me and you know that <|line_break|>
# that i mean to you no more and that you know <|line_break|>
# now so i'm gonna <|line_break|>
# make you laugh no more <|line_break|>
# just me and you know that <|line_break|>
# that i mean to you no more <|line_break|>
# it's over now i'm done saying
# <|verse_break|>
# there's nothing in this life <|line_break|>
# just me and you know that <|line_break|>
# so here's the thing that <|line_break|>
# that's so so sad <|line_break|>
# i'll miss you <|line_break|>
# oh i'll miss so much
# <|verse_break|>
# oh so sorry that i'ma leave <|line_break|>
# but i know you'll be so sad when i'm gone <|line_break|>
# when i'm gone <|line_break|>
# oh so sorry <|line_break|>
# that i'm not gonna make it right <|line_break|>
# it'll take me to make it right
# <|verse_break|>
# oh i'm so sorry sorry <|line_break|>
# oh i'm so sorry sorry <|line_break|>
# oh so sorry <|line_break|>
# yeah i did not mean it like ooh ooh <|line_break|>
# oh so sorry <|line_break|>
# that i'm not gonna make it right <|line_break|>
# i know that you think it's so funny <|line_break|>
# to know that i'm not gonna make it right <|line_break|>
# and i know that you think i did
# <|verse_break|>
# how would you know <|line_break|>
# you're just a fool <|line_break|>
# and i've really tried <|line_break|>
# but it's just like ooh <|line_break|>
# you did not mean it like ooh ooh ooh
# <|verse_break|>
# <|line_break|>
# i'm not afraid to say goodbye <|line_break|>
# i'll be waiting for you <|line_break|>
# to say goodbye <|line_break|>
# so <|UNK|> so say goodbye <|line_break|>
# so ooh
# <|endoftext|>
#
# <|startoftext|>
# i'm out on the town <|line_break|>
# i'm gonna go away <|line_break|>
# oh if you're gonna stay <|line_break|>
# i know it's tough but
# <|verse_break|>
# oh and i just can't stand <|line_break|>
# i'm so glad you found the town <|line_break|>
# oh i just can't stand no more
# <|verse_break|>
# oh i guess i just won't <|line_break|>
# and i just can't stand no more with you <|line_break|>
# i can't i can't make no less of the past
# <|verse_break|>
# i'm just so glad you found the town <|line_break|>
# oh you're going to leave <|line_break|>
# i can't explain why i can't explain why
# <|verse_break|>
# oh and i just can't stand
# <|verse_break
#
# [2210 | 4047.14] loss=0.68 avg=1.22
# [2220 | 4064.09] loss=1.19 avg=1.22
# [2230 | 4081.21] loss=0.86 avg=1.22
# [2240 | 4098.43] loss=0.86 avg=1.21
# [2250 | 4115.59] loss=0.84 avg=1.21
# [2260 | 4132.59] loss=0.96 avg=1.21
# [2270 | 4149.66] loss=0.80 avg=1.20
# [2280 | 4166.77] loss=1.42 avg=1.20
# [2290 | 4183.92] loss=1.22 avg=1.20
# [2300 | 4201.12] loss=1.15 avg=1.20
# [2310 | 4218.26] loss=1.68 avg=1.21
# [2320 | 4235.37] loss=1.50 avg=1.21
# [2330 | 4252.44] loss=1.53 avg=1.22
# [2340 | 4269.51] loss=1.16 avg=1.22
# [2350 | 4286.62] loss=1.48 avg=1.22
# [2360 | 4303.71] loss=1.42 avg=1.22
# [2370 | 4320.79] loss=1.11 avg=1.22
# [2380 | 4337.82] loss=1.07 avg=1.22
# [2390 | 4354.93] loss=1.60 avg=1.22
# [2400 | 4372.11] loss=1.07 avg=1.22
# ======== SAMPLE 1 ========
#  dream <|line_break|>
# come on now <|line_break|>
# it's a bad thing bad but it's a good thing so good <|line_break|>
# this is our song and it all starts off with our hands <|line_break|>
# now that all our hands are in the air it's clear that it was <|UNK|> <|line_break|>
# we had not spoken yet it's too early <|line_break|>
# it's too early now it's too soon now <|line_break|>
# and we'll never tell <|line_break|>
# if a shadow is right on the street <|line_break|>
# or some soul isn't with us <|line_break|>
# well you know they keep me waiting all night long
# <|endoftext|>
#
# <|startoftext|>
# i know that you’re lonely <|line_break|>
# i know that i really don’t wanna be with you <|line_break|>
# i know that i really don’t wanna be with you <|line_break|>
# oh
# <|verse_break|>
# i've had the same dream so many times <|line_break|>
# i've seen you in the morning <|line_break|>
# and you look so sad <|line_break|>
# and you're in the dark with me <|line_break|>
# i just wanna hug you <|line_break|>
# i don’t know if i wanna do it next <|line_break|>
# i don’t know if i wanna do it next <|line_break|>
# i hope it's for the sake of love <|line_break|>
# i hope it's for the sake of love
# <|verse_break|>
# it's been a long time <|line_break|>
# i've been trying to make you smile <|line_break|>
# i've tried to make you smile <|line_break|>
# i've <|UNK|> you in the morning <|line_break|>
# but you're all alone in the <|UNK|> house <|line_break|>
# if he's not coming there won't he be there <|line_break|>
# there's a broken heart in me <|line_break|>
# you've been lying there in the dark that nobody's got to see <|line_break|>
# no you’re just standing there in the rain like a victim of your lies
# <|verse_break|>
# i've had the same dream so many times <|line_break|>
# i've seen you in the morning <|line_break|>
# and you look so sad <|line_break|>
# and you're in the dark with me <|line_break|>
# i just wanna hug you <|line_break|>
# i don’t know if i wanna do it next <|line_break|>
# i don’t know if i wanna do it next <|line_break|>
# i hope it's for the sake of love <|line_break|>
# i hope it's for the sake of love <|line_break|>
# i hope it's for the sake of love <|line_break|>
# i hope it's for the sake of love
# <|verse_break|>
# oh-oh-oh-oh oh-oh-oh-oh oh oh-oh oh-oh
# <|verse_break|>
# i'm feeling sad <|line_break|>
# <|repeat|>
# i don’t care at all <|UNK|> <|line_break|>
# i'm so sad <|line_break|>
# i'm feeling sad <|line_break|>
# i don’t care at all <|UNK|> <|line_break|>
# i'm so sad
# <|verse_break|>
# oh-oh-oh-oh oh-oh-oh-oh oh-oh-oh-oh-oh oh-oh-oh-oh-oh <|line_break|>
# i'm feeling sad <|line_break|>
# <|repeat|>
# i don’t care at all <|UNK|> <|line_break|>
# i'm so sad <|line_break|>
# i'm feeling sad <|line_break|>
# i'm feeling bad
# <|verse_break|>
# i've had the same dream so many times <|
#
# [2410 | 4411.13] loss=1.50 avg=1.22
# [2420 | 4428.10] loss=0.99 avg=1.22
# [2430 | 4445.31] loss=0.52 avg=1.21
# [2440 | 4462.51] loss=1.34 avg=1.21
# [2450 | 4479.68] loss=1.58 avg=1.22
# [2460 | 4496.75] loss=1.22 avg=1.22
# [2470 | 4513.83] loss=1.71 avg=1.22
# [2480 | 4530.91] loss=1.08 avg=1.22
# [2490 | 4547.99] loss=0.85 avg=1.22
# [2500 | 4565.03] loss=1.05 avg=1.22
# Saving checkpoint/run1/model-2500
# [2510 | 4588.76] loss=1.28 avg=1.22
# [2520 | 4606.50] loss=0.72 avg=1.21
# [2530 | 4623.70] loss=1.07 avg=1.21
# [2540 | 4640.62] loss=1.34 avg=1.21
# [2550 | 4657.51] loss=1.42 avg=1.21
# [2560 | 4674.70] loss=0.94 avg=1.21
# [2570 | 4691.98] loss=1.62 avg=1.22
# [2580 | 4709.09] loss=1.00 avg=1.21
# [2590 | 4726.12] loss=1.58 avg=1.22
# [2600 | 4743.17] loss=0.96 avg=1.21
# ======== SAMPLE 1 ========
# _break|>
# and everything you want now now will come you right back <|line_break|>
# but the time won't come in no time soon you'll get that one you want from me <|line_break|>
# 'cause i'm tired of waiting on you <|line_break|>
# and it don't matter what you need <|line_break|>
# you know i don't want it now <|line_break|>
# i'm tired of waiting on you <|line_break|>
# and it don't matter what you need <|line_break|>
# when your time comes you'll get that one you want now from me
# <|endoftext|>
#
# <|startoftext|>
# i got the time i said i'd get in <|line_break|>
# and now here i am at my <|UNK|> desk <|line_break|>
# with my <|UNK|> hat and my pencil <|line_break|>
# but i feel so lonely like i'm sitting at home tonight home <|line_break|>
# and i want some more <|line_break|>
# i got the time i said i'd get in <|line_break|>
# and i feel better so tired home and i just feel cold now
# <|verse_break|>
# i got the time i said i'd get in <|line_break|>
# and now here i am at my <|UNK|> desk <|line_break|>
# with my <|UNK|> hat and my pencil <|line_break|>
# but i feel so lonely like i'm sitting at home tonight home <|line_break|>
# and i want some more <|line_break|>
# i got the time i said i'd get in <|line_break|>
# and now here i am at my <|UNK|> desk <|line_break|>
# with my <|UNK|> hat and my pencil <|line_break|>
# but i feel so lonely i feel so lonely tonight <|line_break|>
# and i i feel i feel like i'm sitting at home tonight <|line_break|>
# and i i feel like i'm sitting at home tonight tonight <|line_break|>
# and i i feel like i'm sitting at home tonight <|line_break|>
# and i i i felt i felt i felt i felt i felt i <|line_break|>
# i felt i felt i felt i felt i felt i was a little bit lonely <|line_break|>
# and i feel like i'm sitting in an empty room tonight <|line_break|>
# watched my tv turn black and i felt it <|line_break|>
# <|UNK|> <|UNK|> tonight <|line_break|>
# and i felt pretty lonely i felt like i was sitting in my own room tonight <|line_break|>
# and i i felt lonely i felt lonely i was so lonely <|line_break|>
# felt lonely i feel i feel like i'm sitting in my own room tonight <|line_break|>
# and i feel lonely i feel lonely i'll be in my own bed tonight <|line_break|>
# and as i think about it i feel this burning inside my stomach i'll feel lonely <|line_break|>
# as i feel myself going down this road i'm going down this road i'm going down this road tonight <|line_break|>
# felt lonely i feel as though i'm going down this road <|line_break|>
# but as i think about it i feel this burning inside my stomach i'll feel lonely <|line_break|>
# as i feel myself going down this road i'm going down this road <|line_break|>
# but as i feel myself going down this road i'm going down i'll feel lonely <|line_break|>
# feeling this way all night <|line_break|>
# feeling lonely i feel as though i'm sitting in my own room tonight <|line_break|>
# feeling lonely lonely lonely feeling kinda lonely lonely lonely lonely lonely lonely lonely <|line_break|>
# feelings i feel inside that's why i feel lonely lonely lonely lonely lonely lonely
# <|verse_break|>
# i got the time i said i'd get in <|line_break|>
# and i feel better so tired home and i just feel cold now <|line_break|>
# and i want some more <|line_break|>
# i got the time i said i'd get in <|line_break|>
#
#
# [2610 | 4782.32] loss=1.64 avg=1.22
# [2620 | 4799.34] loss=1.94 avg=1.23
# [2630 | 4816.46] loss=1.10 avg=1.22
# [2640 | 4833.66] loss=1.12 avg=1.22
# [2650 | 4850.81] loss=0.88 avg=1.22
# [2660 | 4867.84] loss=0.64 avg=1.21
# [2670 | 4884.89] loss=1.02 avg=1.21
# [2680 | 4901.91] loss=0.79 avg=1.21
# [2690 | 4919.03] loss=0.77 avg=1.20
# [2700 | 4936.14] loss=1.36 avg=1.20
# ...
# i said that it was not true <|line_break|>
# and she said it was so so hard <|line_break|>
# said i had to have it for the wrong reasons <|line_break|>
# and i was the wrong one too <|line_break|>
# well she said it was only because i was there <|line_break|>
# there you was the only one i ever loved
# <
#
# [5010 | 9191.79] loss=0.91 avg=1.13
# [5020 | 9208.71] loss=1.12 avg=1.13
# [5030 | 9225.59] loss=0.82 avg=1.13
# [5040 | 9242.67] loss=1.41 avg=1.13
# [5050 | 9259.90] loss=1.27 avg=1.13
# [5060 | 9276.96] loss=2.81 avg=1.15
# [5070 | 9293.99] loss=0.80 avg=1.15
# [5080 | 9311.03] loss=0.76 avg=1.14
# [5090 | 9328.07] loss=1.16 avg=1.14
# [5100 | 9345.13] loss=1.28 avg=1.14
# [5110 | 9362.23] loss=1.91 avg=1.15
# [5120 | 9379.30] loss=1.05 avg=1.15
# [5130 | 9396.36] loss=0.80 avg=1.15
# [5140 | 9413.46] loss=1.07 avg=1.15
# [5150 | 9430.50] loss=1.65 avg=1.15
# [5160 | 9447.60] loss=1.17 avg=1.15
# [5170 | 9464.67] loss=0.85 avg=1.15
# [5180 | 9481.77] loss=1.12 avg=1.15
# [5190 | 9498.90] loss=0.88 avg=1.15
# [5200 | 9516.02] loss=1.26 avg=1.15
# ======== SAMPLE 1 ========
#  guitar on you <|line_break|>
# you got it bad <|line_break|>
# i told you to do good <|line_break|>
# but <|UNK|> done good <|line_break|>
# you're always down <|line_break|>
# <|UNK|> been <|UNK|> good <|line_break|>
# and the <|UNK|> not good <|line_break|>
# 'round the way you be down <|line_break|>
# but i know you <|line_break|>
# you got the whole world on you <|line_break|>
# you got it bad <|line_break|>
# you tell me all the time <|line_break|>
# you got your whole world on you <|line_break|>
# you got it bad <|line_break|>
# i told you to do good <|line_break|>
# but <|UNK|> done good <|line_break|>
# you're always down <|line_break|>
# <|UNK|> been <|UNK|> good <|line_break|>
# and the <|UNK|> not good <|line_break|>
# 'round tha way you be down <|line_break|>
# but i know you <|line_break|>
# i know you got the whole world on you <|line_break|>
# you got it bad <|line_break|>
# you tell me all the time <|line_break|>
# you got your whole world on you <|line_break|>
# you got it bad <|line_break|>
# you tell me all the time <|line_break|>
# you got your whole world on you <|line_break|>
# you got it bad <|line_break|>
# you know you've got a whole lot of <|line_break|>
# on you <|line_break|>
# you've got it bad <|line_break|>
# i told you to do good <|line_break|>
# but <|UNK|> done good <|line_break|>
# you're always down <|line_break|>
# you got your whole world on you <|line_break|>
# you got it bad <|line_break|>
# you tell me all the time <|line_break|>
# you got your whole world on you <|line_break|>
# you got it bad <|line_break|>
# you know you've got a whole lot of
# <|endoftext|>
#
# <|startoftext|>
# taylor <|UNK|> and my brother <|UNK|> <|UNK|> were in prison <|line_break|>
# and they used to laugh i said <|UNK|>
# <|verse_break|>
# and they used to say i could be a big one <|line_break|>
# i used to go off and on and 'bout it <|line_break|>
# 'cause they said the world could take over me <|line_break|>
# now i'm in the world and i can say
# <|verse_break|>
# i don't understand why they tryin' to break me down <|line_break|>
# they couldn't break me at the time <|line_break|>
# so why 'bout a half of what i made <|line_break|>
# now i'm tryin' to break me down down
# <|verse_break|>
# it's just that it's funny how one person <|UNK|> the pain <|line_break|>
# i'll say whatever and nothing else <|UNK|> in return like
# <|verse_break|>
# <|UNK|> <|UNK|> and <|UNK|> and <|UNK|> and my brother's name as well <|line_break|>
# my brother used to be a rapper in prison and his <|UNK|> name as well <|line_break|>
# i didn't see him for a year but i heard he was a <|UNK|> <|line_break|>
# he used to be a <|UNK|> in the summer after every <|UNK|> he had to leave
# <|verse_break|>
# and they used to say i could be a big one <|line_break|>
# i used to go off and on and 'bout it <|
#
# [5210 | 9556.37] loss=0.49 avg=1.14
# [5220 | 9573.37] loss=1.08 avg=1.14
# [5230 | 9590.51] loss=0.85 avg=1.14
# [5240 | 9607.67] loss=1.57 avg=1.14
# [5250 | 9624.70] loss=1.43 avg=1.14
# [5260 | 9641.75] loss=1.02 avg=1.14
# [5270 | 9658.85] loss=0.47 avg=1.14
# [5280 | 9675.95] loss=1.05 avg=1.13
# [5290 | 9693.07] loss=0.88 avg=1.13
# [5300 | 9710.16] loss=0.97 avg=1.13
# [5310 | 9727.22] loss=1.10 avg=1.13
# [5320 | 9744.31] loss=0.97 avg=1.13
# [5330 | 9761.40] loss=1.48 avg=1.13
# [5340 | 9778.52] loss=1.37 avg=1.13
# [5350 | 9795.61] loss=0.83 avg=1.13
# [5360 | 9812.70] loss=1.33 avg=1.13
# [5370 | 9829.77] loss=1.04 avg=1.13
# [5380 | 9846.83] loss=0.44 avg=1.13
# [5390 | 9863.91] loss=1.26 avg=1.13
# [5400 | 9881.02] loss=0.70 avg=1.12
# ======== SAMPLE 1 ========
# |>
# all through the day <|line_break|>
# just give me you give me you <|line_break|>
# <|UNK|> all through the day yeah <|line_break|>
# i can tell by your face <|line_break|>
# all through the day <|line_break|>
# i can tell by your face <|line_break|>
# you got me gone <|line_break|>
# give me one more try my love <|line_break|>
# you got me gone
# <|endoftext|>
#
# <|startoftext|>
# uh uh uh uh
# <|endoftext|>
#
# <|startoftext|>
# yeah uh uh yeah yo yeah <|line_break|>
# hey mami mami why you doing me in <|line_break|>
# hey mami mami why you doing me in mami <|line_break|>
# hey mami mami why you doing me in mami <|line_break|>
# hey mami mami why you doing me in mami
# <|verse_break|>
# you're so fly 'cause your style and your smile put me <|UNK|> <|line_break|>
# i was <|UNK|> <|UNK|> in your hands <|line_break|>
# you're so fly i'm <|UNK|> in your hands <|line_break|>
# say it with me on the track i'm <|UNK|> i'm <|UNK|> to do it <|line_break|>
# <|UNK|> this rap shit i keep it <|UNK|> for the <|UNK|> <|line_break|>
# but the <|UNK|> my <|UNK|> i <|UNK|> to <|UNK|> it <|line_break|>
# and i don't even know your <|UNK|> i ain't giving you no info <|line_break|>
# just stay right there and it'll all come <|UNK|> <|line_break|>
# don't even bother try to take a picture i might lose it <|line_break|>
# just stay right there and it'll all come <|UNK|> <|line_break|>
# i don't even know your <|UNK|> i ain't giving you no info <|line_break|>
# just stay right there and it'll all come <|UNK|> <|line_break|>
# do me in yo
# <|verse_break|>
# i'm just trying to do <|line_break|>
# i'm a real lady try to do me in <|line_break|>
# i'm just trying to do make that bitch <|UNK|> do that bitch <|line_break|>
# <|UNK|> i'm just trying to do just just like <|line_break|>
# <|UNK|> girl try to do me in the <|UNK|> try to do me in the studio <|line_break|>
# i'm just trying to do
# <|verse_break|>
# yo like a real <|UNK|> bitch <|line_break|>
# doin like a real <|UNK|> bitch <|line_break|>
# i'm just trying to do what some dudes gon do <|line_break|>
# don't be tryin to be what some dudes gon do <|line_break|>
# i'm just tryin to be a real bitch tryin to be a real bitch <|line_break|>
# like a real real <|UNK|> bitch <|line_break|>
# don't be tryin to be what some dudes gon do <|line_break|>
# i'm just tryin to be a real bitch just like a real real bitch <|line_break|>
# like a real real <|UNK|> bitch <|line_break|>
# don't be tryin to be what some dudes gon' do <|line_break|>
# i'm just tryin to be a real bitch just like a real bitch
# <|verse_break|>
# don't <|UNK|> with the baddest don't no don't no <|line_break|>
# you don't gotta prove it don't no don't no <|line_break|>
# don't waste my time showin' up to no no
# <|verse_break|>
# i'm just tryin
#
# [5410 | 9920.22] loss=0.84 avg=1.12
# [5420 | 9937.22] loss=0.80 avg=1.12
# [5430 | 9954.35] loss=1.31 avg=1.12
# [5440 | 9971.54] loss=1.69 avg=1.12
# [5450 | 9988.72] loss=0.65 avg=1.12
# [5460 | 10005.84] loss=0.96 avg=1.12
# [5470 | 10022.89] loss=0.82 avg=1.12
# [5480 | 10039.89] loss=0.92 avg=1.11
# [5490 | 10056.91] loss=0.47 avg=1.11
# [5500 | 10073.93] loss=2.06 avg=1.12
# Saving checkpoint/run1/model-5500
# [5510 | 10097.76] loss=0.98 avg=1.11
# [5520 | 10115.44] loss=0.77 avg=1.11
# [5530 | 10132.62] loss=0.80 avg=1.11
# [5540 | 10149.52] loss=1.25 avg=1.11
# [5550 | 10166.45] loss=0.94 avg=1.11
# [5560 | 10183.55] loss=0.97 avg=1.11
# [5570 | 10200.77] loss=1.37 avg=1.11
# [5580 | 10217.89] loss=0.75 avg=1.11
# [5590 | 10234.95] loss=1.55 avg=1.11
# [5600 | 10251.99] loss=1.29 avg=1.11
# ======== SAMPLE 1 ========
# _break|>
# 'cause i'm gonna take you all the way home <|line_break|>
# and when we do you'll always want more <|line_break|>
# and you'll always want more <|line_break|>
# oh i'm gonna take you all the way home <|line_break|>
# i just wanna take you all the way home
# <|endoftext|>
#
# <|startoftext|>
# well we're here a couple seats or there <|line_break|>
# there ain't no room for two of us here's the table <|line_break|>
# we're gonna sit down for the song <|line_break|>
# and all the ladies that are here tonight there's gonna be a row <|line_break|>
# and some men just take the money and they let the man go <|line_break|>
# 'cuz when this old jukebox came out and started singing like the old time <|line_break|>
# and the women were just like oh the ladies they went
# <|verse_break|>
# well we had our meeting at the house of one the girls that works at the church <|line_break|>
# there was a woman singing the blues <|line_break|>
# we had a conversation and we came away <|line_break|>
# she said baby please just come and sing for me <|line_break|>
# and we started singing 'round the corner came out came out my name <|line_break|>
# woman said i took her right out the room <|line_break|>
# and she came and sat down and sat and talked to what it was all about <|line_break|>
# well her eyes looked round and out of the corner there's a little boy <|line_break|>
# well there's a small boy on the floor and some man is singing <|line_break|>
# well he said maybe maybe girl it's time for me to sing sing tonight <|line_break|>
# girl she said just come on come on out baby <|UNK|> <|line_break|>
# there's some other little old <|UNK|> <|line_break|>
# man said the girls say baby it's gone it's gone <|line_break|>
# it was a hell of a crowd and he was singing
# <|verse_break|>
# well the band's going down down the line <|line_break|>
# they came out and they gave out a lot of money for the guys <|line_break|>
# and they had a whole lot of soul in them <|line_break|>
# i <|UNK|> out on my own <|UNK|> <|line_break|>
# all day and down in the line <|line_break|>
# i was singing
# <|verse_break|>
# yeah there's a small girl standing by the door <|line_break|>
# she's singing along just to let me know that i'm standing by her door <|line_break|>
# she's singing along just 'cause she just know he ain't going to leave her <|line_break|>
# they just said maybe she needs a <|UNK|> <|line_break|>
# to make a man understand <|line_break|>
# well there's a little boy in the kitchen stirring up <|line_break|>
# well there's a little girl sitting with him <|line_break|>
# but she was dancing 'cross the <|UNK|> line <|line_break|>
# and there was a big big crowd coming <|line_break|>
# and there was some men banging on the door and banging on the door <|line_break|>
# well there's a little little girl sitting with him <|line_break|>
# and he's dancing 'cross the <|UNK|> line <|line_break|>
# so there was some big bangs coming <|line_break|>
# there were some big bangs coming down the hall <|line_break|>
# some men banging on the door 'cause some men banging on the door <|line_break|>
# yeah they said maybe she needs a <|UNK|> <|line_break|>
# to make some men understand that girl's gone it's gone <|line_break|>
# she was singing
# <|endoftext|>
#
# <|startoftext|>
# well there's a place out on the frontier <|line_break|>
# where the <|UNK|> men and the
#
# [5610 | 10291.28] loss=0.89 avg=1.11
# [5620 | 10308.32] loss=1.08 avg=1.11
# [5630 | 10325.40] loss=1.18 avg=1.11
# [5640 | 10342.61] loss=1.41 avg=1.11
# [5650 | 10359.75] loss=0.51 avg=1.11
# [5660 | 10376.80] loss=1.34 avg=1.11
# [5670 | 10393.83] loss=0.81 avg=1.11
# [5680 | 10410.86] loss=0.91 avg=1.10
# [5690 | 10427.89] loss=1.32 avg=1.11
# [5700 | 10444.92] loss=0.94 avg=1.10
# [5710 | 10461.93] loss=1.94 avg=1.11
# [5720 | 10479.09] loss=1.02 avg=1.11
# [5730 | 10496.26] loss=0.83 avg=1.11
# [5740 | 10513.38] loss=0.62 avg=1.10
# [5750 | 10530.41] loss=1.75 avg=1.11
# [5760 | 10547.41] loss=0.64 avg=1.11
# [5770 | 10564.42] loss=1.69 avg=1.11
# [5780 | 10581.46] loss=1.76 avg=1.12
# [5790 | 10598.53] loss=0.74 avg=1.11
# [5800 | 10615.61] loss=1.23 avg=1.12
# ======== SAMPLE 1 ========
#  to start again <|line_break|>
# i wanna hear if you know
# <-|verse_break|>
# can you hear me right now <|line_break|>
# will you move your body <|line_break|>
# i got something special in my mind <|line_break|>
# can you feel my heartbeat <|line_break|>
# it's making my heart grow weak inside <|line_break|>
# can you feel my heartbeat
# <|verse_break|>
# there's nothing that i can do <|line_break|>
# here i go down on my knees <|line_break|>
# what do you say what do you do <|line_break|>
# can you hear me right now <|line_break|>
# and we'll always be strangers don't you know <|line_break|>
# i don't wanna wake up in your bed in the morning <|line_break|>
# 'cause you are too cold in my body in my head <|line_break|>
# baby if you wanna hear me right now
# <|verse_break|>
# can you hear me right now
# <|endoftext|>
#
# <|startoftext|>
# now that i found out what i was missing <|line_break|>
# i fell in love <|line_break|>
# i finally found you and you got me alone
# <|verse_break|>
# you make me feel so cool <|line_break|>
# you make me feel so fine <|line_break|>
# and i want you everywhere i want you everywhere i want you everywhere i want you everywhere <|line_break|>
# i love everything i love everything i love it baby
# <|verse_break|>
# 'cause i know that you think i don't know what to do <|line_break|>
# my heart <|UNK|> <|line_break|>
# so baby go away and take a chance <|line_break|>
# and if i am lonely tonight <|line_break|>
# baby go back to me
# <|verse_break|>
# and i can feel the passion <|line_break|>
# tired inside <|line_break|>
# my lover <|line_break|>
# baby i need you so bad <|line_break|>
# baby i need you so bad
# <|verse_break|>
# 'cause i know that you <|line_break|>
# think i don't know what to do <|line_break|>
# i can feel it from a mile <|line_break|>
# so baby stay awake <|line_break|>
# and i can feel the passion <|line_break|>
# tired inside <|line_break|>
# my lover <|line_break|>
# baby i need you so bad
# <|verse_break|>
# so go away and take a chance <|line_break|>
# 'cause i need you so bad oh yeah oh yeah baby i need you so bad <|line_break|>
# baby i need you so bad bad bad bad bad bad oh yeah oh-oh yeah oh
# <|verse_break|>
# and i love everything we tried hey hey babe hey sweetheart i love everything we thought it would be hey hey baby i love you baby yeah <|line_break|>
# and i want everything we have and everything we hope we're bringing hey hey sweetheart i love everything we did and everything we're bringing <|line_break|>
# baby i love everything from a distance <|line_break|>
# and i want everything <|line_break|>
# and i want you everywhere i want you everywhere i want you everywhere i want you anytime wherever i wanna go <|line_break|>
# baby i love everything
# <|endoftext|>
#
# <|startoftext|>
# it gets cold in the summer time <|line_break|>
# and i just feel your magic touch <|line_break|>
# i feel your magic touch <|line_break|>
# and i feel my heart start to race
# <|verse_break|>
# and i was on the floor floor floor <|line_break|>
# when you put your arms around me <|line_break|>
# now i see clearly <|line_break|>
# and i am lost in your eyes
# <|verse_break|>
# and i feel nothing i don't feel nothing at all
# <|verse_break|>
# it is hard to breathe so heavy my lungs begin to feel empty <|line_break|>
# and i just feel your magic
#
# [5810 | 10655.43] loss=1.74 avg=1.12
# [5820 | 10672.42] loss=0.75 avg=1.12
# [5830 | 10689.61] loss=0.63 avg=1.11
# [5840 | 10706.76] loss=1.15 avg=1.11
# [5850 | 10723.80] loss=0.81 avg=1.11
# [5860 | 10740.79] loss=1.13 avg=1.11
# [5870 | 10757.81] loss=1.10 avg=1.11
# [5880 | 10774.90] loss=0.84 avg=1.11
# [5890 | 10792.04] loss=1.29 avg=1.11
# [5900 | 10809.27] loss=1.29 avg=1.11
# [5910 | 10826.47] loss=1.37 avg=1.11
# [5920 | 10843.56] loss=1.63 avg=1.12
# [5930 | 10860.61] loss=1.10 avg=1.12
# [5940 | 10877.60] loss=1.00 avg=1.12
# [5950 | 10894.61] loss=1.22 avg=1.12
# [5960 | 10911.61] loss=1.05 avg=1.12
# [5970 | 10928.64] loss=1.08 avg=1.12
# [5980 | 10945.73] loss=1.06 avg=1.12
# [5990 | 10962.88] loss=0.81 avg=1.11
# [6000 | 10980.02] loss=1.20 avg=1.12
# Saving checkpoint/run1/model-6000

# %% [markdown]
# After the model is trained, we can copy the checkpoint folder to Google Drive locally and save the (partially) tuned model.

# %%
gpt2.copy_checkpoint_to_gdrive(run_name='run1')

# %% [markdown]
# Running the next cell will copy the model's checkpoint files from your Google Drive into the Colaboratory VM. This means you can run the code snippets below to start a GPT session and call `generate` without fine-tuning the model. Note that you may have to rerun the imports again

# %%
gpt2.copy_checkpoint_from_gdrive(run_name='run1')

# %%
tf.reset_default_graph()

sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name='run1')
# Out:
# Loading checkpoint checkpoint/run1/model-6000
# INFO:tensorflow:Restoring parameters from checkpoint/run1/model-6000

# %% [markdown]
# Interesting hyperameters of note to `generate`:
#
#
# *   `top_k`: takes the top k guesses from GPT, making this parameter smaller reduces the junk we get
# *   `temperature`: changes how semantically different each run of the generation is to each other. We tried tweaking between 0.7-1.0, and found 0.8 to be a happy medium.
# *   `return_as_list`: if `True`, the function returns each sample as an element in a list. For this instance, each sample represents a song.
# *   `length`: the number of characters to output. This network has a limitation of 1024 characters. During preprocessing, we calculated the average number of characters to a song was ~2000 characters. However in `generate`, we're limited to sampling songs about half that length, a tradeoff from using this network.

# %%
generated_songs = gpt2.generate(sess,
              length=1024,
              temperature=0.8,
              top_k=40,
              prefix=start_token,
              # truncate=end_token,
              include_prefix=True,
              nsamples=5,
              batch_size=5,
              return_as_list=True
              )
print(*generated_songs, sep='\n')

# %% [markdown]
# Write the sample text from `generate` continuously to a text file `results.txt`. Note that `batch_size` must be small, otherwise [this error](https://github.com/tensorflow/models/issues/1993) will notify you that resources are being exhausted. This is why the following code snippet calls `generate` in a loop. Each call to `generate` will sample five songs. We decided to output 40 songs in total for metrics for both here and in the RNN.

# %%
result_file = open("results.txt", "a")

for _ in range(8):
  generated_songs = gpt2.generate(sess,
              length=1024,
              temperature=0.8,
              top_k=40,
              prefix=start_token,
              # truncate=end_token,
              include_prefix=True,
              nsamples=5,
              batch_size=5,
              return_as_list=True
              )
  result_file.write("\n".join(generated_songs))

result_file.close()
